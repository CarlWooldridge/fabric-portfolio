# %%
# %%sql
#
#
# SELECT *
# FROM dbo.taxi_rides_copy_activity_zorder
# WHERE puLocationId IS NOT NULL
# Out:
# StatementMeta(, b0379de7-f6c7-4704-82fb-c33fcd51dbd8, 4, Finished, Available, Finished, False)
# <Spark SQL result set with 1000 rows and 23 fields>
