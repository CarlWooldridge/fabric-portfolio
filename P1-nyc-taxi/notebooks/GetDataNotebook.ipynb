# %%
df = spark.read.format("parquet").load(
    "wasbs://nyctlc@azureopendatastorage.blob.core.windows.net/green/puYear=*/puMonth=*/*.parquet"
)
# Out:
# StatementMeta(, 7f94aa55-bbbb-4549-8b37-365d1b3e59d9, 3, Finished, Available, Finished, False)

# %%
print(df.count())
df.printSchema()
display(df)

# %%
df.write.format("delta").mode("overwrite").saveAsTable("taxi_rides_notebook")
# Out:
# StatementMeta(, 7f94aa55-bbbb-4549-8b37-365d1b3e59d9, 4, Finished, Available, Finished, True)
